# %% [markdown]
# <a href="https://colab.research.google.com/github/dimensionbuster/class2021Fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import IPython.display as ipd

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
def notes(note, duration):
  global all
  
  if(note == 0):
    tmp, t, theta= phasor_sine(1, 10000, duration, C, 0)
    all = np.concatenate((all, tmp*0))
  else:
    tmp, t, theta= phasor_sine(1, 10000, duration, note, 0)
    all = np.concatenate((all, tmp))

# %%
def score_to_notes(score_list):
  for note, dur in score_list:
    notes(note, dur)

# %%
#amp = 1 sr = 10000 임

C = 523
Bb = 466
A = 440
G = 392
F = 349
E = 329

all = np.empty(0)

score_list = [[C, 2*3/8], [Bb, 2*1/8], [A, 2*1/4],[G, 2*1/4],
              [F, 2*1/4],[G, 2*1/4],[ A, 2*1/4],[F, 2*1/4],
              [G, 2*1/8], [A, 2*1/8],[Bb, 2*1/8],[G, 2*1/8],[A, 2*3/8],[G, 2*1/8],
              [F, 2*1/4],[E, 2*1/4],[F, 2*1/4]]

score_to_notes(score_list)

# %%
#debug
print(all)
# Out:
# [3.22728277e-01 6.10919244e-01 8.33731660e-01 ... 4.24641916e-01
#  2.17530012e-01 1.07657502e-14]

# %%
ipd.Audio(all, rate=10000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
